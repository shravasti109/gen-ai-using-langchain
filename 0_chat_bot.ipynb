# %% [markdown]
# #simple llm model

# %%
# !pip install -q langchain langchain-core langchain-groq

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key="",
    temperature=0.7
)

prompt = PromptTemplate(
    template="tell me this in easy and short plz {topic}",
    input_variables=["topic"]
)

topic = input("enter the text u want to ask chatbot: \n")

formatted_prompt = prompt.format(topic=topic)

output = model.invoke(formatted_prompt)

print(output.content)
# Out:
# enter the text u want to ask chatbot:
# hi there wether is so hot do u feel hot too
# Hi, yes it's very hot. I don't feel hot though, I'm just a computer program.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key="",
    temperature=0.9
)

prompt = PromptTemplate(
    template="tell me this in easy and short plz {topic}",
    input_variables=["topic"]
)

topic = input("enter the text u want to ask chatbot: \n")

formatted_prompt = prompt.format(topic=topic)

output = model.invoke(formatted_prompt)

print(output.content)
# Out:
# enter the text u want to ask chatbot:
# hi there wether is so hot do u feel hot too
# Hi, yes it's very hot. I don't feel heat though, I'm just a computer program.
