# %% [markdown]
# #Simple PDF Reader Code using llm application and Langchain

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

load_dotenv()

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=""
)

prompt = PromptTemplate(
    template='Answer the following question \n {question} from the following text - \n {text}',
    input_variables=['question','text']
)

parser = StrOutputParser()

url = 'https://beta.kelicalix.com/profile/shendeshravasti335'
loader = WebBaseLoader(url)

docs = loader.load()


chain = prompt | model | parser

print(chain.invoke({'question':'tell me baout this page plz?', 'text':docs[0].page_content}))
# Out:
# /tmp/ipykernel_1886/3292048581.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import WebBaseLoader
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# The page appears to be about "Kelicalix", which is described as a "Self-Improvement Social Platform". This suggests that Kelicalix is an online platform or community that focuses on helping users improve themselves, possibly through social interactions, resources, and support. Would you like to know more about what features or services Kelicalix might offer?
